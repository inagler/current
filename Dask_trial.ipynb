# %%
#!/usr/bin/env python3
# inagler 12/09/23

import numpy as np
import xarray as xr
import glob
import pop_tools
import dask.distributed

path = '/Data/gfi/share/ModData/CESM2_LENS2/ocean/monthly/vvel/'
files = glob.glob(path + '*.nc')

grid_name = 'POP_gx1v7'

region_defs = {
    'NorthAtlantic':[{'match': {'REGION_MASK': [6]}, 'bounds': {'TLAT': [-20.0, 66.0]}}],
    'LabradorSea': [{'match': {'REGION_MASK': [8]}, 'bounds': {'TLAT': [45.0, 66.0]}}],
    'MediterraneanSea': [{'match': {'REGION_MASK': [7]}}]
}
mask3d = pop_tools.region_mask_3d(grid_name, region_defs=region_defs, mask_name='North Atlantic')
mask3d = mask3d.sum('region')

len_time = 3012
dept_time_series_maxi = np.zeros((len_time, len(files)))
dept_time_series_rapi = np.zeros((len_time, len(files)))
dept_time_series_spgy = np.zeros((len_time, len(files)))

print('initialization complete')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# initialization complete

# %%
def depth_MOC(ds):
    overturning_depth = (ds.VVEL * ds.dz * ds.DXU).sum(dim='nlon').cumsum(dim='z_t') * 1e-6
    maxi = overturning_depth.isel(z_t=slice(27, 51)).max(dim=['nlat','z_t']).values
    rapi = overturning_depth.isel(nlat=274, z_t=slice(27, 51)).max(dim='z_t').values
    spgy = overturning_depth.isel(nlat=345, z_t=slice(27, 51)).max(dim='z_t').values
    return maxi, rapi, spgy

@dask.delayed
def process_file(file):
    ds = xr.open_dataset(file).where(mask3d == 1)
    
    # Update units to SI units
    ds['VVEL'] *= 1e-2
    ds['dz'] *= 1e-2
    ds['z_t'] *= 1e-2
    ds['z_w_top'] *= 1e-2
    ds['z_w_bot'] *= 1e-2
    ds['DXU'] *= 1e-2
    ds['VVEL'].attrs['units'] = 'm/s'
    ds['dz'].attrs['units'] = 'm'
    ds['z_t'].attrs['units'] = 'm'
    ds['z_w_top'].attrs['units'] = 'm'
    ds['z_w_bot'].attrs['units'] = 'm'
    ds['DXU'].attrs['units'] = 'm'
    
    return depth_MOC(ds)

# %% [markdown]
# These lines below are responsible for parallelizing the processing of multiple files using Dask. Let's break down what each line does:
#
# with `dask.distributed.Client()` as `client`:: This line creates a Dask client, which is used to manage distributed computing. When you create a Dask client, it connects to a Dask cluster (which can be local or distributed) and provides an interface for parallel and distributed computing. The with statement ensures that the client is properly closed when the block is exited.
#
# `results = dask.compute(*[process_file(file) for filein files], scheduler='threads'`: In this line, a list comprehension is used to create a list of delayed objects by calling the process_file(file) function for each file in the files list. Each `process_file(file) call is wrapped in a Dask delayed object, which represents a computation that can be executed lazily and in parallel.
# - `dask.compute` is then used to compute the results of all the delayed objects in parallel. The scheduler='threads' argument specifies that Dask should use a multi-threaded scheduler for parallel execution. This means that Dask will use multiple CPU threads to execute the delayed computations concurrently, which can speed up the processing of multiple
# - `he `*` operator is used to unpack the list of delayed objects and pass them as separate arguments to dask.compute.
# The results of the computations are stored in the results variable, which will be  tuple containing the results f - each delayed computation.

# %%
# Use concurrent.futures to parallelize file processing
with dask.distributed.Client() as client:
    results = dask.compute(*[process_file(file) for file in files], scheduler='threads')
# Out:
# /home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/node.py:183: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35807 instead
#   warnings.warn(
# /home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/dask/base.py:1367: UserWarning: Running on a single-machine scheduler when a distributed client is active might lead to unexpected results.
#   warnings.warn(
# 2023-09-15 14:57:27,190 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:27,188 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:27,215 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:27,247 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:27,246 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:27,254 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:27,259 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:27,263 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:27,294 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:58,186 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:58,189 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:58,215 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:58,238 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:58,239 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:58,254 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:57:58,260 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:58:29,259 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:58:29,220 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:58:29,256 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:58:29,238 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:58:29,186 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# ...
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:58:29,190 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 14:58:29,238 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 328, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1215, in heartbeat
#     response = await retry_operation(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1160, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1381, in connect
#     return await connect_attempt
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 1317, in _connect
#     comm = await connect(
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/comm/core.py", line 333, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33888 after 30 s
# 2023-09-15 15:12:42,993 - distributed.scheduler - WARNING - Worker failed to heartbeat within 300 seconds. Closing: <WorkerState 'tcp://127.0.0.1:37289', name: 4, status: running, memory: 0, processing: 0>
# 2023-09-15 15:12:43,001 - distributed.scheduler - WARNING - Worker failed to heartbeat within 300 seconds. Closing: <WorkerState 'tcp://127.0.0.1:39699', name: 8, status: running, memory: 0, processing: 0>
# 2023-09-15 15:12:43,002 - distributed.scheduler - WARNING - Worker failed to heartbeat within 300 seconds. Closing: <WorkerState 'tcp://127.0.0.1:42289', name: 1, status: running, memory: 0, processing: 0>
# 2023-09-15 15:12:43,003 - distributed.scheduler - WARNING - Worker failed to heartbeat within 300 seconds. Closing: <WorkerState 'tcp://127.0.0.1:43562', name: 7, status: running, memory: 0, processing: 0>
# 2023-09-15 15:12:43,004 - distributed.scheduler - WARNING - Worker failed to heartbeat within 300 seconds. Closing: <WorkerState 'tcp://127.0.0.1:45348', name: 2, status: running, memory: 0, processing: 0>
# 2023-09-15 15:12:43,010 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:42289'.
# 2023-09-15 15:12:43,012 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:45348'.
# 2023-09-15 15:12:43,012 - distributed.worker - ERROR - Scheduler was unaware of this worker 'tcp://127.0.0.1:42289'. Shutting down.
# 2023-09-15 15:12:43,014 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:39699'.
# 2023-09-15 15:12:43,014 - distributed.worker - ERROR - Scheduler was unaware of this worker 'tcp://127.0.0.1:45348'. Shutting down.
# 2023-09-15 15:12:43,015 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:37289'.
# 2023-09-15 15:12:43,017 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:43562'.
# 2023-09-15 15:12:43,017 - distributed.worker - ERROR - Scheduler was unaware of this worker 'tcp://127.0.0.1:37289'. Shutting down.
# 2023-09-15 15:12:43,017 - distributed.worker - ERROR - Scheduler was unaware of this worker 'tcp://127.0.0.1:39699'. Shutting down.
# 2023-09-15 15:12:43,023 - distributed.worker - ERROR - Scheduler was unaware of this worker 'tcp://127.0.0.1:43562'. Shutting down.
# ERROR:asyncio.events:
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils.py", line 742, in wrapper
#     return await func(*args, **kwargs)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1497, in close
#     await self.finished()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 448, in finished
#     await self._event_finished.wait()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/locks.py", line 214, in wait
#     await fut
# asyncio.exceptions.CancelledError
# ERROR:asyncio.events:
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils.py", line 742, in wrapper
#     return await func(*args, **kwargs)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1497, in close
#     await self.finished()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 448, in finished
#     await self._event_finished.wait()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/locks.py", line 214, in wait
#     await fut
# asyncio.exceptions.CancelledError
# ERROR:asyncio.events:
# Traceback (most recent call last):
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/utils.py", line 742, in wrapper
#     return await func(*args, **kwargs)
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/worker.py", line 1497, in close
#     await self.finished()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/site-packages/distributed/core.py", line 448, in finished
#     await self._event_finished.wait()
#   File "/home/innag3580/.conda/envs/cartopy/lib/python3.10/asyncio/locks.py", line 214, in wait
#     await fut
# asyncio.exceptions.CancelledError
# 2023-09-15 15:12:45,293 - distributed.nanny - WARNING - Restarting worker
# 2023-09-15 15:12:45,322 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-09-15 15:12:45,322 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-09-15 15:12:45,358 - distributed.nanny - WARNING - Restarting worker
# 2023-09-15 15:12:45,639 - distributed.nanny - WARNING - Restarting worker
# 2023-09-15 15:12:45,645 - distributed.nanny - WARNING - Restarting worker
# 2023-09-15 15:12:45,701 - distributed.nanny - WARNING - Restarting worker
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 # Use concurrent.futures to parallelize file processing
#       2 with dask.distributed.Client() as client:
# ----> 3     results = dask.compute(*[process_file(file) for file in files], scheduler='threads')
#
# File ~/.conda/envs/cartopy/lib/python3.10/site-packages/dask/base.py:600, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     597     keys.append(x.__dask_keys__())
#     598     postcomputes.append(x.__dask_postcompute__())
# --> 600 results = schedule(dsk, keys, **kwargs)
#     601 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/.conda/envs/cartopy/lib/python3.10/site-packages/dask/threaded.py:89, in get(dsk, keys, cache, num_workers, pool, **kwargs)
#      86     elif isinstance(pool, multiprocessing.pool.Pool):
#      87         pool = MultiprocessingPoolExecutor(pool)
# ---> 89 results = get_async(
#      90     pool.submit,
#      91     pool._max_workers,
#      92     dsk,
#      93     keys,
#      94     cache=cache,
#      95     get_id=_thread_get_id,
#      96     pack_exception=pack_exception,
#      97     **kwargs,
#      98 )
#     100 # Cleanup pools associated to dead threads
#     101 with pools_lock:
#
# File ~/.conda/envs/cartopy/lib/python3.10/site-packages/dask/local.py:511, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     509         _execute_task(task, data)  # Re-execute locally
#     510     else:
# --> 511         raise_exception(exc, tb)
#     512 res, worker_id = loads(res_info)
#     513 state["cache"][key] = res
#
# File ~/.conda/envs/cartopy/lib/python3.10/site-packages/dask/local.py:319, in reraise(exc, tb)
#     317 if exc.__traceback__ is not tb:
#     318     raise exc.with_traceback(tb)
# --> 319 raise exc
#
# File ~/.conda/envs/cartopy/lib/python3.10/site-packages/dask/local.py:224, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     222 try:
#     223     task, data = loads(task_info)
# --> 224     result = _execute_task(task, data)
#     225     id = get_id()
#     226     result = dumps((result, id))
#
# File ~/.conda/envs/cartopy/lib/python3.10/site-packages/dask/core.py:119, in _execute_task(arg, cache, dsk)
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# Input In [2], in process_file(file)
#      13 ds['VVEL'] *= 1e-2
#      14 ds['dz'] *= 1e-2
# ---> 15 ds['z_t'] *= 1e-2
#      16 ds['z_w_top'] *= 1e-2
#      17 ds['z_w_bot'] *= 1e-2
#
# File ~/.conda/envs/cartopy/lib/python3.10/site-packages/xarray/core/_typed_ops.py:293, in DataArrayOpsMixin.__imul__(self, other)
#     292 def __imul__(self, other):
# --> 293     return self._inplace_binary_op(other, operator.imul)
#
# File ~/.conda/envs/cartopy/lib/python3.10/site-packages/xarray/core/dataarray.py:4382, in DataArray._inplace_binary_op(self, other, f)
#    4380 try:
#    4381     with self.coords._merge_inplace(other_coords):
# -> 4382         f(self.variable, other_variable)
#    4383 except MergeError as exc:
#    4384     raise MergeError(
#    4385         "Automatic alignment is not supported for in-place operations.\n"
#    4386         "Consider aligning the indices manually or using a not-in-place operation.\n"
#    4387         "See https://github.com/pydata/xarray/issues/3910 for more explanations."
#    4388     ) from exc
#
# File ~/.conda/envs/cartopy/lib/python3.10/site-packages/xarray/core/_typed_ops.py:483, in VariableOpsMixin.__imul__(self, other)
#     482 def __imul__(self, other):
# --> 483     return self._inplace_binary_op(other, operator.imul)
#
# File ~/.conda/envs/cartopy/lib/python3.10/site-packages/xarray/core/variable.py:3062, in IndexVariable._inplace_binary_op(self, other, f)
#    3061 def _inplace_binary_op(self, other, f):
# -> 3062     raise TypeError(
#    3063         "Values of an IndexVariable are immutable and can not be modified inplace"
#    3064     )
#
# TypeError: Values of an IndexVariable are immutable and can not be modified inplace

# %%
# Unpack results
for i, result in enumerate(results):
    dept_time_series_maxi[:, i], dept_time_series_rapi[:, i], dept_time_series_spgy[:, i] = result
    print('file', i+1, '/', len(files), 'executed')

print('computation finished')

# %%
# Save time series to a single file
np.save("timeseries/maxi_dens_time_series.npy", dept_time_series_maxi)
np.save("timeseries/rapi_dens_time_series.npy", dept_time_series_rapi)
np.save("timeseries/spgy_dens_time_series.npy", dept_time_series_spgy)

print('saving successful')

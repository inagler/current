# %%
import xarray as xr
import pop_tools
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import cartopy

# %%
filename = '/Data/gfi/share/ModData/CESM2_LENS2/ocean/monthly/shf/shf_1001.001.nc'

# %%
ds_shf = xr.open_dataset(filename)

# %%
ds_shf.SHF.isel(time=slice(0,12)).mean(dim='time').plot()
plt.savefig('/home/innag3580/phase1_CONDA/results/shf.png', bbox_inches='tight')
